# %% [markdown]
# Question 1: What is Simple Linear Regression (SLR)? Explain its purpose.

# %% [markdown]
# Answer:
# Simple Linear Regression (SLR) is a supervised learning algorithm used to model the relationship between one independent variable (X) and one dependent variable (Y) by fitting a straight line to observed data.
#
# Purpose:
#
# To predict the value of a dependent variable based on an independent variable
#
# To understand the strength and direction of the relationship between variables
#
# To identify trends and make future forecasts

# %% [markdown]
# Question 2: What are the key assumptions of Simple Linear Regression?

# %% [markdown]
# Answer:
# The key assumptions of Simple Linear Regression are:
#
# 1 Linearity – There is a linear relationship between X and Y
#
# 2 Independence – Observations are independent of each other
#
# 3 Homoscedasticity – Constant variance of errors across all values of X
#
# 4 Normality – Residuals (errors) are normally distributed
#
# 5 No multicollinearity – Only one independent variable is used

# %% [markdown]
# Question 3: Write the mathematical equation for a simple linear regression model and explain each term.

# %% [markdown]
# Answer:
#                              Y=β0​+β1​X+
# Where:
#
# Y = Dependent variable
#
# X = Independent variable
#
# β₀ (Intercept) = Value of Y when X = 0
#
# β₁ (Slope) = Change in Y for one unit change in X
#
# ε (Error term) = Random erro

# %% [markdown]
# Question 4: Provide a real-world example where simple linear regression can be applied.

# %% [markdown]
# Answer:
# A real-world example is predicting house prices based on area.
#
# Independent variable: House area (sq. ft.)
#
# Dependent variable: House price
#
# Simple linear regression helps estimate how price changes with area.

# %% [markdown]
# Question 5: What is the method of least squares in linear regression?

# %% [markdown]
# Answer:
# The method of least squares is a technique used to find the best-fit regression line by minimizing the sum of squared differences between actual and predicted values.
#
# Its goal is to reduce prediction errors and produce the most accurate line.

# %% [markdown]
# Question 6: What is Logistic Regression? How does it differ from Linear Regression?

# %% [markdown]
# Answer:
# Logistic Regression is a supervised learning algorithm used for classification problems, especially binary outcomes like Yes/No or 0/1.
# | Feature  | Linear Regression | Logistic Regression |
# | -------- | ----------------- | ------------------- |
# | Output   | Continuous values | Probability (0–1)   |
# | Use      | Prediction        | Classification      |
# | Function | Straight line     | Sigmoid curve       |

# %% [markdown]
# Question 7: Name and briefly describe three common evaluation metrics for regression models.

# %% [markdown]
# Answer:
#
# Mean Absolute Error (MAE) – Average of absolute errors
#
# Mean Squared Error (MSE) – Average of squared errors
#
# Root Mean Squared Error (RMSE) – Square root of MSE, sensitive to large errors

# %% [markdown]
# Question 8: What is the purpose of the R-squared metric in regression analysis?

# %% [markdown]
# Answer:
# R-squared (R²) measures how well the regression model explains the variation in the dependent variable.
#
# Value ranges from 0 to 1
#
# Higher value indicates better model fit
#
# Example: R² = 0.8 means 80% of variance is explained by the model

# %% [markdown]
# Question 9: Write Python code to fit a simple linear regression model using scikit-learn and print the slope and intercept.

# %% [markdown]
# Answer:

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

# Sample data
X = np.array([10, 20, 30, 40, 50]).reshape(-1, 1)
Y = np.array([15, 35, 45, 55, 70])

# Create model
model = LinearRegression()
model.fit(X, Y)

# Print slope and intercept
print("Slope:", model.coef_[0])
print("Intercept:", model.intercept_)
# Out:
# Slope: 1.3
# Intercept: 5.0

# %% [markdown]
# Question 10: How do you interpret the coefficients in a simple linear regression model?

# %% [markdown]
# Answer:
#
# Intercept (β₀): Predicted value of Y when X = 0
#
# Slope (β₁): Change in Y for every one-unit increase in X
#
# Example:
# If slope = 2, then Y increases by 2 units when X increases by 1 unit.
